# %%
import IPython
from google.colab import output

display(IPython.display.Javascript('''
 function ClickConnect(){
   btn = document.querySelector("colab-connect-button")
   if (btn != null){
     console.log("Click colab-connect-button"); 
     btn.click() 
     }
   
   btn = document.getElementById('ok')
   if (btn != null){
     console.log("Click reconnect"); 
     btn.click() 
     }
  }
  
setInterval(ClickConnect,60000)
'''))

print("Done.")
# Out:
# Done.

# %%
#Mount Google Drive as folder
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Thesis/IUNet
# Out:
# /content/drive/MyDrive/Thesis/IUNet

# %%
# !pip install -q -r requirements.txt
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#      |████████████████████████████████| 282 kB 5.0 MB/s
#      |████████████████████████████████| 9.5 MB 59.4 MB/s
#      |████████████████████████████████| 6.8 MB 56.1 MB/s
#      |████████████████████████████████| 61 kB 668 kB/s
#      |████████████████████████████████| 70 kB 10.5 MB/s
#      |████████████████████████████████| 1.7 MB 61.9 MB/s
#      |████████████████████████████████| 829 kB 53.4 MB/s
#      |████████████████████████████████| 125 kB 68.2 MB/s
#      |████████████████████████████████| 596 kB 69.8 MB/s
#      |████████████████████████████████| 574 kB 65.2 MB/s
#      |████████████████████████████████| 37.1 MB 1.3 MB/s
#      |████████████████████████████████| 948 kB 39.5 MB/s
#      |████████████████████████████████| 1.3 MB 57.8 MB/s
#      |████████████████████████████████| 139 kB 69.2 MB/s
# ...

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard

# %%
# !python train.py -c modules/cnn/config/config_feature_extract.yml
# Out:
# ########################ArgParseSummaryStart########################
# ------------------positional arguments-----------------
# -------------------optional arguments------------------
#   c                        : modules/cnn/config/config_feature_extract.yml
# ---------------------Model options---------------------
#   model                    : cnn.TwoHeadInception3
# --------------------Dataset options--------------------
#   data_root                : /content/drive/MyDrive/Thesis
#   dataset                  : cholec80_feature_extract.Cholec80FeatureExtract
#   out_features             : 7
#   train_percent_check      : 1.0
#   val_percent_check        : 1.0
#   test_percent_check       : 1.0
#   overfit_pct              : 0.0
#   input_height             : 299
#   input_width              : 299
# ---------------------Module options--------------------
#   module                   : cnn.feature_extraction.FeatureExtraction
# ...

# %%
# !kill 1217
#%tensorboard --logdir /content/drive/MyDrive/Thesis/IUNet/tb_photo4
# %tensorboard --logdir /content/drive/MyDrive/Thesis/IUNet/logs/run04/tb/version_0

# %%
# !python train.py -c modules/mstcn/config/config_tcn.yml

# %%
# %tensorboard --logdir /content/drive/MyDrive/Thesis/IUNet/logs/210827-231752_IUNet_Cholec80_mstcn_MultiStageModel/tb/version_0
