# %%
#Mount Google Drive as folder
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Thesis/IUNet
# Out:
# /content/drive/MyDrive/Thesis/IUNet

# %%
from modified_create_dataframe import write_pkl
#from modified_create_dataframe import write_pkl

root_dir = '/content/drive/MyDrive/Thesis/cholec80'

write_pkl(root_dir)

# %%
import pickle

pa = '/content/drive/MyDrive/Thesis/cholec80/dataframes/cholec_split_250px_25fps.pkl'

with open(pa, 'rb') as f:
    df = pickle.load(f)
    
print(df)
# Out:
#                         image_path class  ... tool_Irrigator tool_SpecimenBag
# 0       video01/video01_000001.png     0  ...              0                0
# 1       video01/video01_000002.png     0  ...              0                0
# 2       video01/video01_000003.png     0  ...              0                0
# 3       video01/video01_000004.png     0  ...              0                0
# 4       video01/video01_000005.png     0  ...              0                0
# ...                            ...   ...  ...            ...              ...
# 184493  video80/video80_001720.png     6  ...              0                0
# 184494  video80/video80_001721.png     6  ...              0                0
# 184495  video80/video80_001722.png     6  ...              0                0
# 184496  video80/video80_001723.png     6  ...              0                0
# 184497  video80/video80_001724.png     6  ...              0                0
#
# [184498 rows x 11 columns]

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df1=df.head(10)
df1.to_excel("Cholec Head.xlsx")

# %%
df2=df.tail(10)
df2.to_excel("Cholec Tail.xlsx")

# %%
i=1
while i>0:
  print(i)
  i+=1

# %%
# !python /content/drive/MyDrive/Thesis/IUNet/utils/iunet/dataset_stats.py
# Out:
# stats for cholec....
#
#
#   0% 0/80 [00:00<?, ?it/s]video01 length: 0
# video02 length: 0
# video03 length: 0
# video04 length: 0
# video05 length: 0
# video06 length: 0
# video07 length: 0
# video08 length: 0
# video09 length: 0
# video10 length: 0
# video11 length: 0
# video12 length: 0
# video13 length: 0
# video14 length: 0
# video15 length: 0
# video16 length: 0
# video17 length: 0
# video18 length: 0
# video19 length: 0
# video20 length: 0
# video21 length: 0
# video22 length: 0
# video23 length: 0
# video24 length: 0
# video25 length: 0
# video26 length: 0
# video27 length: 0
# video28 length: 0
# video29 length: 0
# video30 length: 0
# video31 length: 0
# video32 length: 0
# video33 length: 0
# video34 length: 0
# video35 length: 0
# video36 length: 0
# video37 length: 0
# video38 length: 0
# video39 length: 0
# video40 length: 0
# video41 length: 0
# video42 length: 0
# video43 length: 0
# video44 length: 0
# video45 length: 0
# video46 length: 0
# video47 length: 0
# ...
